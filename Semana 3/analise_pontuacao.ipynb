# %% [markdown]
# # Análise dos Dados

# %%
import pandas as pd

# %%
df = pd.read_csv('desafio1.csv')

# %%
df.head(5)
# Out:
#    RowNumber                                        id  \
# 0          1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 1          2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 2          3  774bc378f787438c9c7594e536787d07a097a54b
# 3          4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 4          5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
#
#                                   sobrenome  pontuacao_credito  \
# 0  6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 1  48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 2  f2b29d5d934de615812b697132e767dea0f1e9e2                502
# 3  85d5c9da7cddd8109ad32a6c348fe2bb10bf99f2                699
# 4  ddc89c837a6933639de75f28171057060bd322df                850
#
#   estado_residencia genero  idade  nivel_estabilidade  saldo_conta  \
# 0                SC      F     42                   2         0.00
# 1                RS      F     41                   1     83807.86
# ...

# %%
df.dtypes
# Out:
# RowNumber                     int64
# id                           object
# sobrenome                    object
# pontuacao_credito             int64
# estado_residencia            object
# genero                       object
# idade                         int64
# nivel_estabilidade            int64
# saldo_conta                 float64
# numero_produtos               int64
# possui_cartao_de_credito      int64
# membro_ativo                  int64
# dtype: object

# %%
df.isna().sum()
# Out:
# RowNumber                   0
# id                          0
# sobrenome                   0
# pontuacao_credito           0
# estado_residencia           0
# genero                      0
# idade                       0
# nivel_estabilidade          0
# saldo_conta                 0
# numero_produtos             0
# possui_cartao_de_credito    0
# membro_ativo                0
# dtype: int64

# %%
df['estado_residencia'].value_counts()
# Out:
# SC    3519
# RS    1750
# PR    1731
# Name: estado_residencia, dtype: int64

# %% [markdown]
# # Paraná (PR)

# %%
df_pr = df.query('estado_residencia == "PR"')

# %%
df_pr.head()
# Out:
#     RowNumber                                        id  \
# 7           8  6704b822c203e2dda9f225dfc4f1bed2ae9044e6
# 15         16  04a488f5afe23bc8e0bc2dab36b7ef31a2175465
# 16         17  5970b1f277e0c09c2fbdf5c0b2961e286d1eee8a
# 26         27  93f9d14870d4e1f4b406e822aeda2522034e36a7
# 28         29  29696d097f5af397971553e03af3d72544a2de43
#
#                                    sobrenome  pontuacao_credito  \
# 7   336b42483e6a17f48eb040a251b5d6e64d1351a9                376
# 15  ae50d67a10a428f042478724f8696faad69c16e7                616
# 16  b7e8d8eaaffa2e0990b222ca486b9c2426c2cd7e                653
# 26  190ad954707e053c18af1de13a140cb70a6ff58c                756
# 28  bb0562f482fc937e49bca1fbce8619797d02a123                574
#
#    estado_residencia genero  idade  nivel_estabilidade  saldo_conta  \
# 7                 PR      F     29                   4    115046.74
# 15                PR      M     45                   3    143129.41
# ...

# %%
pr_media = df_pr['pontuacao_credito'].mean()
pr_media
# Out:
# 648.9612940496822

# %%
pr_mediana = df_pr['pontuacao_credito'].median()
pr_mediana
# Out:
# 650.0

# %%
pr_desvio = df_pr['pontuacao_credito'].std()
pr_desvio
# Out:
# 98.60718591309772

# %%
pr_moda = df_pr['pontuacao_credito'].mode()
pr_moda[0]
# Out:
# 850

# %% [markdown]
# # Rio Grande do Sul (RS)

# %%
df_rs = df.query('estado_residencia == "RS"')

# %%
df_rs.head()
# Out:
#     RowNumber                                        id  \
# 1           2  28dcb083ad90512da16b9430085c2cddb8ca5e12
# 4           5  37b3bb8ca243955fb3605ec7e1c2a4607cdb3b22
# 5           6  db5cf32c3fbc7c5d8f8313afca1d099de6dc055f
# 11         12  727d2911ca645148ecb222005c5f4f8ccf72b4d6
# 14         15  4f883154a84d3fda402e17686bfe212558f7f15e
#
#                                    sobrenome  pontuacao_credito  \
# 1   48e1ad846796fa314f1b4a6702b83343eb5482c5                608
# 4   ddc89c837a6933639de75f28171057060bd322df                850
# 5   a596384ca70664af4c5fac9f935cff186b8e8bc0                645
# 11  a1009913e51c3c11ef2e88eda344ec5befa13fd4                497
# 14  2ad0c93dcf651c0afe5e5aa7a8778f7c3ec5769e                635
#
#    estado_residencia genero  idade  nivel_estabilidade  saldo_conta  \
# 1                 RS      F     41                   1     83807.86
# 4                 RS      F     43                   2    125510.82
# ...

# %%
rs_media = df_rs['pontuacao_credito'].mean()
rs_media
# Out:
# 651.1051428571428

# %%
rs_mediana = df_rs['pontuacao_credito'].median()
rs_mediana
# Out:
# 650.0

# %%
rs_desvio = df_rs['pontuacao_credito'].std()
rs_desvio
# Out:
# 95.1365984138357

# %%
rs_moda = df_rs['pontuacao_credito'].mode()
rs_moda[0]
# Out:
# 850

# %% [markdown]
# # Santa Catarina (SC)

# %%
df_sc = df.query('estado_residencia == "SC"')

# %%
df_sc.head(5)
# Out:
#    RowNumber                                        id  \
# 0          1  e7f44fcbd380d4cef7e6c232cc7e37895c3fd197
# 2          3  774bc378f787438c9c7594e536787d07a097a54b
# 3          4  043a71326f7096de155e7f0c559dc62b5e4b7239
# 6          7  8f3cc64a0a84bab38fefb030f09757d0cbf03bb2
# 8          9  35f41954a87f722a3960e5fa8ce898a09398a564
#
#                                   sobrenome  pontuacao_credito  \
# 0  6d6e0aa1b9b413e442e2fb68df14b4fc3f91de50                619
# 2  f2b29d5d934de615812b697132e767dea0f1e9e2                502
# 3  85d5c9da7cddd8109ad32a6c348fe2bb10bf99f2                699
# 6  abec3e525ab40e45975c91d4fa2bc7b318d93de4                822
# 8  53a417796c777851003b3f2431e8eef5625ec15b                501
#
#   estado_residencia genero  idade  nivel_estabilidade  saldo_conta  \
# 0                SC      F     42                   2         0.00
# 2                SC      F     42                   8    159660.80
# ...

# %%
sc_media = df_sc['pontuacao_credito'].mean()
sc_media
# Out:
# 649.5376527422563

# %%
sc_mediana = df_sc['pontuacao_credito'].median()
sc_mediana
# Out:
# 653.0

# %%
sc_desvio = df_sc['pontuacao_credito'].std()
sc_desvio
# Out:
# 97.23349279343306

# %%
sc_moda = df_sc['pontuacao_credito'].mode()
sc_moda[0]
# Out:
# 850

# %% [markdown]
# # Resposta

# %%
resp = {"SC": {"moda": sc_moda[0], "mediana":sc_mediana, "media": sc_media, "desvio_padrao":sc_desvio}, "RS": {"moda":rs_moda[0], "mediana": rs_mediana, "media":rs_media, "desvio_padrao":rs_desvio}, "PR": {"moda": pr_moda[0], "mediana": pr_mediana, "media": pr_media, "desvio_padrao": pr_desvio}}

# %%
df_resp = pd.DataFrame(resp)
df_resp
# Out:
#                        SC          RS          PR
# moda           850.000000  850.000000  850.000000
# mediana        653.000000  650.000000  650.000000
# media          649.537653  651.105143  648.961294
# desvio_padrao   97.233493   95.136598   98.607186

# %%
df_resp.to_json('submission.json')
